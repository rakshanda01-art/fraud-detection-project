# %% [markdown]
# # Quick EDA
# This notebook previews the synthetic fraud dataset. Run the cells after data generation.

# %%
import pandas as pd
df = pd.read_csv('data/raw/synthetic_fraud.csv')
df.head()

# %%
df['is_fraud'].value_counts(normalize=True)
